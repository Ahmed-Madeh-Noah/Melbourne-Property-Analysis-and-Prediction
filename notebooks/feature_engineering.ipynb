# %% [markdown]
# # Feature Engineering
# This notebook handles:
# 1. Separating Street Names and Types
# 2. Calculate Property Age
# 3. Calculate Average Room Size
# 4. Calculate Building Area to Land Area Ratio

# %%
import pandas as pd

df = pd.read_csv("../data/CLEANED_Melbourne_Housing_Market.csv")
df["SaleDate"] = pd.to_datetime(df["SaleDate"])
df.head()
# Out:
#     SaleDate      Suburb           Address UnitType  SaleMethod  \
# 0 2016-03-12  Abbotsford      85_Turner_St    House        Sold
# 1 2016-04-02  Abbotsford   25_Bloomburg_St    House        Sold
# 2 2017-04-03  Abbotsford      5_Charles_St    House  Sold_Prior
# 3 2017-04-03  Abbotsford  40_Federation_La    House   Passed_In
# 4 2016-04-06  Abbotsford       55A_Park_St    House  Vendor_Bid
#
#   RealEstateAgent CouncilArea             RegionName  Rooms  DistanceToCBD  \
# 0          Biggin  Yarra_City  Northern_Metropolitan    2.0            2.5
# 1          Biggin  Yarra_City  Northern_Metropolitan    2.0            2.5
# 2          Biggin  Yarra_City  Northern_Metropolitan    3.0            2.5
# 3          Biggin  Yarra_City  Northern_Metropolitan    3.0            2.5
# 4          Nelson  Yarra_City  Northern_Metropolitan    4.0            2.5
#
#    ...  Bedrooms  Bathrooms  CarSpots  LandSize  BuildingArea  YearBuilt  \
# 0  ...       2.0        1.0       1.0     202.0         133.0     1970.0
# 1  ...       2.0        1.0       0.0     156.0          79.0     1900.0
# 2  ...       3.0        2.0       0.0     134.0         150.0     1900.0
# 3  ...       3.0        2.0       1.0      94.0         133.0     1970.0
# 4  ...       3.0        1.0       2.0     120.0         142.0     2014.0
#
#    Latitude  Longitude  NeighbouringProperties      Price
# 0  -37.7996   144.9984                  4019.0  1480000.0
# 1  -37.8079   144.9934                  4019.0  1035000.0
# 2  -37.8093   144.9944                  4019.0  1465000.0
# 3  -37.7969   144.9969                  4019.0   850000.0
# 4  -37.8072   144.9941                  4019.0  1600000.0
#
# [5 rows x 21 columns]

# %%
from data_manipulation import feature_engineering as fe

# %% [markdown]
# ## Separating Street Names and Types

# %%
df[["StreetName", "StreetType"]] = df.apply(fe.separate_address, axis=1)
df["StreetType"] = df.apply(fe.get_full_street_type, axis=1)
df = fe.remove_column(df, "Address")
df.head()
# Out:
#     SaleDate      Suburb UnitType  SaleMethod RealEstateAgent CouncilArea  \
# 0 2016-03-12  Abbotsford    House        Sold          Biggin  Yarra_City
# 1 2016-04-02  Abbotsford    House        Sold          Biggin  Yarra_City
# 2 2017-04-03  Abbotsford    House  Sold_Prior          Biggin  Yarra_City
# 3 2017-04-03  Abbotsford    House   Passed_In          Biggin  Yarra_City
# 4 2016-04-06  Abbotsford    House  Vendor_Bid          Nelson  Yarra_City
#
#               RegionName  Rooms  DistanceToCBD  Postcode  ...  CarSpots  \
# 0  Northern_Metropolitan    2.0            2.5    3067.0  ...       1.0
# 1  Northern_Metropolitan    2.0            2.5    3067.0  ...       0.0
# 2  Northern_Metropolitan    3.0            2.5    3067.0  ...       0.0
# 3  Northern_Metropolitan    3.0            2.5    3067.0  ...       1.0
# 4  Northern_Metropolitan    4.0            2.5    3067.0  ...       2.0
#
#    LandSize  BuildingArea  YearBuilt  Latitude  Longitude  \
# 0     202.0         133.0     1970.0  -37.7996   144.9984
# 1     156.0          79.0     1900.0  -37.8079   144.9934
# 2     134.0         150.0     1900.0  -37.8093   144.9944
# 3      94.0         133.0     1970.0  -37.7969   144.9969
# 4     120.0         142.0     2014.0  -37.8072   144.9941
#
#    NeighbouringProperties      Price  StreetName  StreetType
# 0                  4019.0  1480000.0      Turner      Street
# 1                  4019.0  1035000.0   Bloomburg      Street
# 2                  4019.0  1465000.0     Charles      Street
# 3                  4019.0   850000.0  Federation        Lane
# 4                  4019.0  1600000.0        Park      Street
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Calculate Property Age

# %%
df["PropertyAge"] = df.apply(fe.calc_property_age, axis=1)
df.head()
# Out:
#     SaleDate      Suburb UnitType  SaleMethod RealEstateAgent CouncilArea  \
# 0 2016-03-12  Abbotsford    House        Sold          Biggin  Yarra_City
# 1 2016-04-02  Abbotsford    House        Sold          Biggin  Yarra_City
# 2 2017-04-03  Abbotsford    House  Sold_Prior          Biggin  Yarra_City
# 3 2017-04-03  Abbotsford    House   Passed_In          Biggin  Yarra_City
# 4 2016-04-06  Abbotsford    House  Vendor_Bid          Nelson  Yarra_City
#
#               RegionName  Rooms  DistanceToCBD  Postcode  ...  LandSize  \
# 0  Northern_Metropolitan    2.0            2.5    3067.0  ...     202.0
# 1  Northern_Metropolitan    2.0            2.5    3067.0  ...     156.0
# 2  Northern_Metropolitan    3.0            2.5    3067.0  ...     134.0
# 3  Northern_Metropolitan    3.0            2.5    3067.0  ...      94.0
# 4  Northern_Metropolitan    4.0            2.5    3067.0  ...     120.0
#
#    BuildingArea  YearBuilt  Latitude  Longitude  NeighbouringProperties  \
# 0         133.0     1970.0  -37.7996   144.9984                  4019.0
# 1          79.0     1900.0  -37.8079   144.9934                  4019.0
# 2         150.0     1900.0  -37.8093   144.9944                  4019.0
# 3         133.0     1970.0  -37.7969   144.9969                  4019.0
# 4         142.0     2014.0  -37.8072   144.9941                  4019.0
#
#        Price  StreetName  StreetType  PropertyAge
# 0  1480000.0      Turner      Street         46.0
# 1  1035000.0   Bloomburg      Street        116.0
# 2  1465000.0     Charles      Street        117.0
# 3   850000.0  Federation        Lane         47.0
# 4  1600000.0        Park      Street          2.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Calculate Average Room Size

# %%
df["AvgRoomSize"] = df.apply(fe.calc_avg_room_size, axis=1)
df.head()
# Out:
#     SaleDate      Suburb UnitType  SaleMethod RealEstateAgent CouncilArea  \
# 0 2016-03-12  Abbotsford    House        Sold          Biggin  Yarra_City
# 1 2016-04-02  Abbotsford    House        Sold          Biggin  Yarra_City
# 2 2017-04-03  Abbotsford    House  Sold_Prior          Biggin  Yarra_City
# 3 2017-04-03  Abbotsford    House   Passed_In          Biggin  Yarra_City
# 4 2016-04-06  Abbotsford    House  Vendor_Bid          Nelson  Yarra_City
#
#               RegionName  Rooms  DistanceToCBD  Postcode  ...  BuildingArea  \
# 0  Northern_Metropolitan    2.0            2.5    3067.0  ...         133.0
# 1  Northern_Metropolitan    2.0            2.5    3067.0  ...          79.0
# 2  Northern_Metropolitan    3.0            2.5    3067.0  ...         150.0
# 3  Northern_Metropolitan    3.0            2.5    3067.0  ...         133.0
# 4  Northern_Metropolitan    4.0            2.5    3067.0  ...         142.0
#
#    YearBuilt  Latitude  Longitude  NeighbouringProperties      Price  \
# 0     1970.0  -37.7996   144.9984                  4019.0  1480000.0
# 1     1900.0  -37.8079   144.9934                  4019.0  1035000.0
# 2     1900.0  -37.8093   144.9944                  4019.0  1465000.0
# 3     1970.0  -37.7969   144.9969                  4019.0   850000.0
# 4     2014.0  -37.8072   144.9941                  4019.0  1600000.0
#
#    StreetName  StreetType  PropertyAge  AvgRoomSize
# 0      Turner      Street         46.0    66.500000
# 1   Bloomburg      Street        116.0    39.500000
# 2     Charles      Street        117.0    50.000000
# 3  Federation        Lane         47.0    44.333333
# 4        Park      Street          2.0    35.500000
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Calculate Building Area to Land Area Ratio

# %%
df["BuildingToLandRatio"] = df.apply(fe.calc_building_to_land_ratio, axis=1)
df.head()
# Out:
#     SaleDate      Suburb UnitType  SaleMethod RealEstateAgent CouncilArea  \
# 0 2016-03-12  Abbotsford    House        Sold          Biggin  Yarra_City
# 1 2016-04-02  Abbotsford    House        Sold          Biggin  Yarra_City
# 2 2017-04-03  Abbotsford    House  Sold_Prior          Biggin  Yarra_City
# 3 2017-04-03  Abbotsford    House   Passed_In          Biggin  Yarra_City
# 4 2016-04-06  Abbotsford    House  Vendor_Bid          Nelson  Yarra_City
#
#               RegionName  Rooms  DistanceToCBD  Postcode  ...  YearBuilt  \
# 0  Northern_Metropolitan    2.0            2.5    3067.0  ...     1970.0
# 1  Northern_Metropolitan    2.0            2.5    3067.0  ...     1900.0
# 2  Northern_Metropolitan    3.0            2.5    3067.0  ...     1900.0
# 3  Northern_Metropolitan    3.0            2.5    3067.0  ...     1970.0
# 4  Northern_Metropolitan    4.0            2.5    3067.0  ...     2014.0
#
#    Latitude  Longitude  NeighbouringProperties      Price  StreetName  \
# 0  -37.7996   144.9984                  4019.0  1480000.0      Turner
# 1  -37.8079   144.9934                  4019.0  1035000.0   Bloomburg
# 2  -37.8093   144.9944                  4019.0  1465000.0     Charles
# 3  -37.7969   144.9969                  4019.0   850000.0  Federation
# 4  -37.8072   144.9941                  4019.0  1600000.0        Park
#
#    StreetType  PropertyAge  AvgRoomSize  BuildingToLandRatio
# 0      Street         46.0    66.500000             0.658416
# 1      Street        116.0    39.500000             0.506410
# 2      Street        117.0    50.000000             1.119403
# 3        Lane         47.0    44.333333             1.414894
# 4      Street          2.0    35.500000             1.183333
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Engineered Data Saving

# %%
df.head()
# Out:
#     SaleDate      Suburb UnitType  SaleMethod RealEstateAgent CouncilArea  \
# 0 2016-03-12  Abbotsford    House        Sold          Biggin  Yarra_City
# 1 2016-04-02  Abbotsford    House        Sold          Biggin  Yarra_City
# 2 2017-04-03  Abbotsford    House  Sold_Prior          Biggin  Yarra_City
# 3 2017-04-03  Abbotsford    House   Passed_In          Biggin  Yarra_City
# 4 2016-04-06  Abbotsford    House  Vendor_Bid          Nelson  Yarra_City
#
#               RegionName  Rooms  DistanceToCBD  Postcode  ...  YearBuilt  \
# 0  Northern_Metropolitan    2.0            2.5    3067.0  ...     1970.0
# 1  Northern_Metropolitan    2.0            2.5    3067.0  ...     1900.0
# 2  Northern_Metropolitan    3.0            2.5    3067.0  ...     1900.0
# 3  Northern_Metropolitan    3.0            2.5    3067.0  ...     1970.0
# 4  Northern_Metropolitan    4.0            2.5    3067.0  ...     2014.0
#
#    Latitude  Longitude  NeighbouringProperties      Price  StreetName  \
# 0  -37.7996   144.9984                  4019.0  1480000.0      Turner
# 1  -37.8079   144.9934                  4019.0  1035000.0   Bloomburg
# 2  -37.8093   144.9944                  4019.0  1465000.0     Charles
# 3  -37.7969   144.9969                  4019.0   850000.0  Federation
# 4  -37.8072   144.9941                  4019.0  1600000.0        Park
#
#    StreetType  PropertyAge  AvgRoomSize  BuildingToLandRatio
# 0      Street         46.0    66.500000             0.658416
# 1      Street        116.0    39.500000             0.506410
# 2      Street        117.0    50.000000             1.119403
# 3        Lane         47.0    44.333333             1.414894
# 4      Street          2.0    35.500000             1.183333
#
# [5 rows x 25 columns]

# %%
df.to_csv("../data/ENGINEERED_Melbourne_Housing_Market.csv", index=False)

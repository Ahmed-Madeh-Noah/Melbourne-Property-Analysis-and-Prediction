# %% [markdown]
# # Feature Engineering
# This notebook handles:
# 1. Separating Street Names and Types
# 2. Calculate Property Age
# 3. Calculate Average Room Size
# 4. Calculate Building Area to Land Area Ratio

# %%
import pandas as pd

df = pd.read_csv("../data/CLEANED_Melbourne_Housing_Market.csv")
df["SaleDate"] = pd.to_datetime(df["SaleDate"])
df.head()
# Out:
#     SaleDate           Address CouncilArea RealEstateAgent  \
# 0 2016-03-12      85_Turner_St  Yarra_City          Biggin
# 1 2016-04-02   25_Bloomburg_St  Yarra_City          Biggin
# 2 2017-04-03      5_Charles_St  Yarra_City          Biggin
# 3 2017-04-03  40_Federation_La  Yarra_City          Biggin
# 4 2016-04-06       55A_Park_St  Yarra_City          Nelson
#
#               RegionName  SaleMethod      Suburb UnitType  Bathrooms  \
# 0  Northern_Metropolitan        Sold  Abbotsford    House        1.0
# 1  Northern_Metropolitan        Sold  Abbotsford    House        1.0
# 2  Northern_Metropolitan  Sold_Prior  Abbotsford    House        2.0
# 3  Northern_Metropolitan   Passed_In  Abbotsford    House        2.0
# 4  Northern_Metropolitan  Vendor_Bid  Abbotsford    House        1.0
#
#    Bedrooms  ...  CarSpots  DistanceToCBD  LandSize  Latitude  Longitude  \
# 0       2.0  ...       1.0            2.5     202.0  -37.7996   144.9984
# 1       2.0  ...       0.0            2.5     156.0  -37.8079   144.9934
# 2       3.0  ...       0.0            2.5     134.0  -37.8093   144.9944
# 3       3.0  ...       1.0            2.5      94.0  -37.7969   144.9969
# 4       3.0  ...       2.0            2.5     120.0  -37.8072   144.9941
#
#    NeighbouringProperties  Postcode  Rooms  YearBuilt      Price
# 0                  4019.0    3067.0    2.0     1970.0  1480000.0
# 1                  4019.0    3067.0    2.0     1900.0  1035000.0
# 2                  4019.0    3067.0    3.0     1900.0  1465000.0
# 3                  4019.0    3067.0    3.0     1970.0   850000.0
# 4                  4019.0    3067.0    4.0     2014.0  1600000.0
#
# [5 rows x 21 columns]

# %%
from data_manipulation import feature_engineering as fe

# %% [markdown]
# ## Separating Street Names and Types

# %%
df[["StreetName", "StreetType"]] = df.apply(fe.separate_address, axis=1)
df["StreetType"] = df.apply(fe.get_full_street_type, axis=1)
df = fe.remove_column(df, "Address")
df.head()
# Out:
#     SaleDate CouncilArea RealEstateAgent             RegionName  SaleMethod  \
# 0 2016-03-12  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 1 2016-04-02  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 2 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan  Sold_Prior
# 3 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan   Passed_In
# 4 2016-04-06  Yarra_City          Nelson  Northern_Metropolitan  Vendor_Bid
#
#        Suburb UnitType  Bathrooms  Bedrooms  BuildingArea  ...  LandSize  \
# 0  Abbotsford    House        1.0       2.0         133.0  ...     202.0
# 1  Abbotsford    House        1.0       2.0          79.0  ...     156.0
# 2  Abbotsford    House        2.0       3.0         150.0  ...     134.0
# 3  Abbotsford    House        2.0       3.0         133.0  ...      94.0
# 4  Abbotsford    House        1.0       3.0         142.0  ...     120.0
#
#    Latitude  Longitude  NeighbouringProperties  Postcode  Rooms  YearBuilt  \
# 0  -37.7996   144.9984                  4019.0    3067.0    2.0     1970.0
# 1  -37.8079   144.9934                  4019.0    3067.0    2.0     1900.0
# 2  -37.8093   144.9944                  4019.0    3067.0    3.0     1900.0
# 3  -37.7969   144.9969                  4019.0    3067.0    3.0     1970.0
# 4  -37.8072   144.9941                  4019.0    3067.0    4.0     2014.0
#
#        Price  StreetName  StreetType
# 0  1480000.0      Turner      Street
# 1  1035000.0   Bloomburg      Street
# 2  1465000.0     Charles      Street
# 3   850000.0  Federation        Lane
# 4  1600000.0        Park      Street
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Calculate Property Age

# %%
df["PropertyAge"] = df.apply(fe.calc_property_age, axis=1)
df.head()
# Out:
#     SaleDate CouncilArea RealEstateAgent             RegionName  SaleMethod  \
# 0 2016-03-12  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 1 2016-04-02  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 2 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan  Sold_Prior
# 3 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan   Passed_In
# 4 2016-04-06  Yarra_City          Nelson  Northern_Metropolitan  Vendor_Bid
#
#        Suburb UnitType  Bathrooms  Bedrooms  BuildingArea  ...  Latitude  \
# 0  Abbotsford    House        1.0       2.0         133.0  ...  -37.7996
# 1  Abbotsford    House        1.0       2.0          79.0  ...  -37.8079
# 2  Abbotsford    House        2.0       3.0         150.0  ...  -37.8093
# 3  Abbotsford    House        2.0       3.0         133.0  ...  -37.7969
# 4  Abbotsford    House        1.0       3.0         142.0  ...  -37.8072
#
#    Longitude  NeighbouringProperties  Postcode  Rooms  YearBuilt      Price  \
# 0   144.9984                  4019.0    3067.0    2.0     1970.0  1480000.0
# 1   144.9934                  4019.0    3067.0    2.0     1900.0  1035000.0
# 2   144.9944                  4019.0    3067.0    3.0     1900.0  1465000.0
# 3   144.9969                  4019.0    3067.0    3.0     1970.0   850000.0
# 4   144.9941                  4019.0    3067.0    4.0     2014.0  1600000.0
#
#    StreetName  StreetType  PropertyAge
# 0      Turner      Street         46.0
# 1   Bloomburg      Street        116.0
# 2     Charles      Street        117.0
# 3  Federation        Lane         47.0
# 4        Park      Street          2.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Calculate Average Room Size

# %%
df["AvgRoomSize"] = df.apply(fe.calc_avg_room_size, axis=1)
df.head()
# Out:
#     SaleDate CouncilArea RealEstateAgent             RegionName  SaleMethod  \
# 0 2016-03-12  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 1 2016-04-02  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 2 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan  Sold_Prior
# 3 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan   Passed_In
# 4 2016-04-06  Yarra_City          Nelson  Northern_Metropolitan  Vendor_Bid
#
#        Suburb UnitType  Bathrooms  Bedrooms  BuildingArea  ...  Longitude  \
# 0  Abbotsford    House        1.0       2.0         133.0  ...   144.9984
# 1  Abbotsford    House        1.0       2.0          79.0  ...   144.9934
# 2  Abbotsford    House        2.0       3.0         150.0  ...   144.9944
# 3  Abbotsford    House        2.0       3.0         133.0  ...   144.9969
# 4  Abbotsford    House        1.0       3.0         142.0  ...   144.9941
#
#    NeighbouringProperties  Postcode  Rooms  YearBuilt      Price  StreetName  \
# 0                  4019.0    3067.0    2.0     1970.0  1480000.0      Turner
# 1                  4019.0    3067.0    2.0     1900.0  1035000.0   Bloomburg
# 2                  4019.0    3067.0    3.0     1900.0  1465000.0     Charles
# 3                  4019.0    3067.0    3.0     1970.0   850000.0  Federation
# 4                  4019.0    3067.0    4.0     2014.0  1600000.0        Park
#
#    StreetType  PropertyAge  AvgRoomSize
# 0      Street         46.0    66.500000
# 1      Street        116.0    39.500000
# 2      Street        117.0    50.000000
# 3        Lane         47.0    44.333333
# 4      Street          2.0    35.500000
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Calculate Building Area to Land Area Ratio

# %%
df["BuildingToLandRatio"] = df.apply(fe.calc_building_to_land_ratio, axis=1)
df.head()
# Out:
#     SaleDate CouncilArea RealEstateAgent             RegionName  SaleMethod  \
# 0 2016-03-12  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 1 2016-04-02  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 2 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan  Sold_Prior
# 3 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan   Passed_In
# 4 2016-04-06  Yarra_City          Nelson  Northern_Metropolitan  Vendor_Bid
#
#        Suburb UnitType  Bathrooms  Bedrooms  BuildingArea  ...  \
# 0  Abbotsford    House        1.0       2.0         133.0  ...
# 1  Abbotsford    House        1.0       2.0          79.0  ...
# 2  Abbotsford    House        2.0       3.0         150.0  ...
# 3  Abbotsford    House        2.0       3.0         133.0  ...
# 4  Abbotsford    House        1.0       3.0         142.0  ...
#
#    NeighbouringProperties  Postcode  Rooms  YearBuilt      Price  StreetName  \
# 0                  4019.0    3067.0    2.0     1970.0  1480000.0      Turner
# 1                  4019.0    3067.0    2.0     1900.0  1035000.0   Bloomburg
# 2                  4019.0    3067.0    3.0     1900.0  1465000.0     Charles
# 3                  4019.0    3067.0    3.0     1970.0   850000.0  Federation
# 4                  4019.0    3067.0    4.0     2014.0  1600000.0        Park
#
#    StreetType  PropertyAge  AvgRoomSize  BuildingToLandRatio
# 0      Street         46.0    66.500000             0.658416
# 1      Street        116.0    39.500000             0.506410
# 2      Street        117.0    50.000000             1.119403
# 3        Lane         47.0    44.333333             1.414894
# 4      Street          2.0    35.500000             1.183333
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Engineered Data Saving

# %%
from data_manipulation.data_cleaning import reorder_df_columns

df = reorder_df_columns(df)
df.head()
# Out:
#     SaleDate CouncilArea RealEstateAgent             RegionName  SaleMethod  \
# 0 2016-03-12  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 1 2016-04-02  Yarra_City          Biggin  Northern_Metropolitan        Sold
# 2 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan  Sold_Prior
# 3 2017-04-03  Yarra_City          Biggin  Northern_Metropolitan   Passed_In
# 4 2016-04-06  Yarra_City          Nelson  Northern_Metropolitan  Vendor_Bid
#
#    StreetName StreetType      Suburb UnitType  AvgRoomSize  ...  \
# 0      Turner     Street  Abbotsford    House    66.500000  ...
# 1   Bloomburg     Street  Abbotsford    House    39.500000  ...
# 2     Charles     Street  Abbotsford    House    50.000000  ...
# 3  Federation       Lane  Abbotsford    House    44.333333  ...
# 4        Park     Street  Abbotsford    House    35.500000  ...
#
#    DistanceToCBD  LandSize  Latitude  Longitude  NeighbouringProperties  \
# 0            2.5     202.0  -37.7996   144.9984                  4019.0
# 1            2.5     156.0  -37.8079   144.9934                  4019.0
# 2            2.5     134.0  -37.8093   144.9944                  4019.0
# 3            2.5      94.0  -37.7969   144.9969                  4019.0
# 4            2.5     120.0  -37.8072   144.9941                  4019.0
#
#    Postcode  PropertyAge  Rooms  YearBuilt      Price
# 0    3067.0         46.0    2.0     1970.0  1480000.0
# 1    3067.0        116.0    2.0     1900.0  1035000.0
# 2    3067.0        117.0    3.0     1900.0  1465000.0
# 3    3067.0         47.0    3.0     1970.0   850000.0
# 4    3067.0          2.0    4.0     2014.0  1600000.0
#
# [5 rows x 25 columns]

# %%
df.to_csv("../data/ENGINEERED_Melbourne_Housing_Market.csv", index=False)

# %% [markdown]
# # Data Cleaning
# This notebook handles:
# 1. Dataset Format Unifying
# 2. Nulls Estimation
# 3. Duplicates Removal
# 4. Outlier Handling

# %%
import pandas as pd

df = pd.read_csv("data/Melbourne_Housing_Market.csv")
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Dataset Format Unifying

# %%
df.rename(columns={"Type": "UnitType", "Method": "SaleMethod", "SellerG": "RealEstateAgent", "Date": "SaleDate",
                   "Distance": "DistanceToCBD", "Bedroom2": "Bedrooms", "Bathroom": "Bathrooms", "Car": "CarSpots",
                   "Landsize": "LandSize", "Lattitude": "Latitude", "Longtitude": "Longitude",
                   "Regionname": "RegionName", "Propertycount": "NeighbouringProperties"}, inplace=True)
df.head()
# Out:
#        Suburb             Address  Rooms UnitType      Price SaleMethod  \
# 0  Abbotsford       68 Studley St      2        h        NaN         SS
# 1  Abbotsford        85 Turner St      2        h  1480000.0          S
# 2  Abbotsford     25 Bloomburg St      2        h  1035000.0          S
# 3  Abbotsford  18/659 Victoria St      3        u        NaN         VB
# 4  Abbotsford        5 Charles St      3        h  1465000.0         SP
#
#   RealEstateAgent   SaleDate  DistanceToCBD  Postcode  ...  Bathrooms  \
# 0          Jellis  3/09/2016            2.5    3067.0  ...        1.0
# 1          Biggin  3/12/2016            2.5    3067.0  ...        1.0
# 2          Biggin  4/02/2016            2.5    3067.0  ...        1.0
# 3          Rounds  4/02/2016            2.5    3067.0  ...        2.0
# 4          Biggin  4/03/2017            2.5    3067.0  ...        2.0
#
#    CarSpots  LandSize  BuildingArea  YearBuilt         CouncilArea Latitude  \
# 0       1.0     126.0           NaN        NaN  Yarra City Council -37.8014
# 1       1.0     202.0           NaN        NaN  Yarra City Council -37.7996
# 2       0.0     156.0          79.0     1900.0  Yarra City Council -37.8079
# 3       1.0       0.0           NaN        NaN  Yarra City Council -37.8114
# 4       0.0     134.0         150.0     1900.0  Yarra City Council -37.8093
#
#    Longitude             RegionName NeighbouringProperties
# 0   144.9958  Northern Metropolitan                 4019.0
# 1   144.9984  Northern Metropolitan                 4019.0
# 2   144.9934  Northern Metropolitan                 4019.0
# 3   145.0116  Northern Metropolitan                 4019.0
# 4   144.9944  Northern Metropolitan                 4019.0
#
# [5 rows x 21 columns]

# %%
df["StreetName"] = df["Address"].str.extract(r"^\S+\s(\w+)\s")
df["StreetType"] = df["Address"].str.extract(r".*\s(\w+)$")
df.drop(columns=["Address"], inplace=True)
df.head()
# Out:
#        Suburb  Rooms UnitType      Price SaleMethod RealEstateAgent  \
# 0  Abbotsford      2        h        NaN         SS          Jellis
# 1  Abbotsford      2        h  1480000.0          S          Biggin
# 2  Abbotsford      2        h  1035000.0          S          Biggin
# 3  Abbotsford      3        u        NaN         VB          Rounds
# 4  Abbotsford      3        h  1465000.0         SP          Biggin
#
#     SaleDate  DistanceToCBD  Postcode  Bedrooms  ...  LandSize  BuildingArea  \
# 0  3/09/2016            2.5    3067.0       2.0  ...     126.0           NaN
# 1  3/12/2016            2.5    3067.0       2.0  ...     202.0           NaN
# 2  4/02/2016            2.5    3067.0       2.0  ...     156.0          79.0
# 3  4/02/2016            2.5    3067.0       3.0  ...       0.0           NaN
# 4  4/03/2017            2.5    3067.0       3.0  ...     134.0         150.0
#
#    YearBuilt         CouncilArea  Latitude Longitude             RegionName  \
# 0        NaN  Yarra City Council  -37.8014  144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996  144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079  144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114  145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093  144.9944  Northern Metropolitan
#
#    NeighbouringProperties StreetName  StreetType
# 0                  4019.0    Studley          St
# 1                  4019.0     Turner          St
# 2                  4019.0  Bloomburg          St
# 3                  4019.0   Victoria          St
# 4                  4019.0    Charles          St
#
# [5 rows x 22 columns]

# %%
streetTypeAbbreviations = {"St": "Street", "Rd": "Road", "Av": "Avenue", "Ct": "Court", "Dr": "Drive", "Cr": "Crescent",
                           "Gr": "Grove", "Pl": "Place", "Pde": "Parade", "Cl": "Close", "Wy": "Way", "La": "Lane",
                           "Bvd": "Boulevard", "Tce": "Terrace", "Cct": "Circuit", "Hwy": "Highway", "Avenue": "Avenue",
                           "Ri": "Rise", "Wk": "Walk", "Mw": "Meander Way", "Boulevard": "Boulevard", "Sq": "Square",
                           "Parade": "Parade", "Esplanade": "Esplanade", "N": "North", "Qd": "Quay", "Cir": "Circle",
                           "Vw": "View", "S": "South", "Crescent": "Crescent", "Prm": "Promenade", "Gdns": "Gardens",
                           "W": "West", "Strand": "Strand", "Grove": "Grove", "Ridge": "Ridge", "Vs": "Views",
                           "Ch": "Chase", "Fairway": "Fairway", "Righi": "Right", "E": "East", "Grn": "Green",
                           "Wyn": "Way", "Gln": "Glen", "Esp": "Esplanade", "Bnd": "Bend", "Mews": "Mews",
                           "Rdg": "Ridge", "Lp": "Loop", "Crest": "Crest", "Grange": "Grange", "Crossway": "Crossway",
                           "Pky": "Parkway", "Gra": "Grange", "Rt": "Route", "Res": "Reserve", "Wky": "Way",
                           "East": "East", "Lk": "Lake", "Nk": "Nook", "Gwy": "Gateway", "Mall": "Mall",
                           "Highway": "Highway", "Ambl": "Ambleside", "Terrace": "Terrace", "Pt": "Point",
                           "Parkway": "Parkway", "Street": "Street", "Corso": "Corso", "Outlook": "Outlook",
                           "Media": "Media", "Hub": "Hub", "Crofts": "Crofts", "Victoria": "Victoria", "Nth": "North",
                           "Athol": "Athol", "Nook": "Nook", "Rise": "Rise", "Greenway": "Greenway", "Views": "Views",
                           "street": "Street", "Hl": "Hill", "Glade": "Glade", "Cove": "Cove", "Qy": "Quay",
                           "Lairidge": "Lairidge", "Scala": "Scala", "Broadway": "Broadway", "Road": "Road",
                           "Prst": "Prestwick", "Grand": "Grand", "Loop": "Loop", "Eyrie": "Eyrie", "Dell": "Dell",
                           "Gve": "Grove", "Pkt": "Pocket", "Al": "Alley", "West": "West", "Hts": "Heights",
                           "Aveue": "Avenue", "Summit": "Summit", "Ave": "Avenue", "Woodland": "Woodland",
                           "Edg": "Edge", "Skyline": "Skyline", "Out": "Outlook", "Range": "Range", "Hth": "Heath",
                           "Atrium": "Atrium", "Gables": "Gables", "Mears": "Mears", "App": "Approach", "Brk": "Brook",
                           "Spur": "Spur", "Court": "Court", "Pass": "Pass", "Gld": "Gold", "Crse": "Course",
                           "Ps": "Passage", "Entrance": "Entrance", "Heights": "Heights", "Boulevarde": "Boulevarde",
                           "Circuit": "Circuit", "Parks": "Parks", "Ridgeway": "Ridgeway", "Panorama": "Panorama",
                           "Briars": "Briars"}
df["StreetType"] = df["StreetType"].replace(streetTypeAbbreviations)
df.head()
# Out:
#        Suburb  Rooms UnitType      Price SaleMethod RealEstateAgent  \
# 0  Abbotsford      2        h        NaN         SS          Jellis
# 1  Abbotsford      2        h  1480000.0          S          Biggin
# 2  Abbotsford      2        h  1035000.0          S          Biggin
# 3  Abbotsford      3        u        NaN         VB          Rounds
# 4  Abbotsford      3        h  1465000.0         SP          Biggin
#
#     SaleDate  DistanceToCBD  Postcode  Bedrooms  ...  LandSize  BuildingArea  \
# 0  3/09/2016            2.5    3067.0       2.0  ...     126.0           NaN
# 1  3/12/2016            2.5    3067.0       2.0  ...     202.0           NaN
# 2  4/02/2016            2.5    3067.0       2.0  ...     156.0          79.0
# 3  4/02/2016            2.5    3067.0       3.0  ...       0.0           NaN
# 4  4/03/2017            2.5    3067.0       3.0  ...     134.0         150.0
#
#    YearBuilt         CouncilArea  Latitude Longitude             RegionName  \
# 0        NaN  Yarra City Council  -37.8014  144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996  144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079  144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114  145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093  144.9944  Northern Metropolitan
#
#    NeighbouringProperties StreetName  StreetType
# 0                  4019.0    Studley      Street
# 1                  4019.0     Turner      Street
# 2                  4019.0  Bloomburg      Street
# 3                  4019.0   Victoria      Street
# 4                  4019.0    Charles      Street
#
# [5 rows x 22 columns]

# %%
floatColumns = ["DistanceToCBD", "BuildingArea", "Latitude", "Longitude"]
intColumns = [column for column in df.select_dtypes(exclude=object).columns if column not in floatColumns]
for column in intColumns:
    df[column] = pd.to_numeric(df[column], errors="coerce").astype("Int64")
df.head()
# Out:
#        Suburb  Rooms UnitType    Price SaleMethod RealEstateAgent   SaleDate  \
# 0  Abbotsford      2        h     <NA>         SS          Jellis  3/09/2016
# 1  Abbotsford      2        h  1480000          S          Biggin  3/12/2016
# 2  Abbotsford      2        h  1035000          S          Biggin  4/02/2016
# 3  Abbotsford      3        u     <NA>         VB          Rounds  4/02/2016
# 4  Abbotsford      3        h  1465000         SP          Biggin  4/03/2017
#
#    DistanceToCBD  Postcode  Bedrooms  ...  LandSize  BuildingArea  YearBuilt  \
# 0            2.5      3067         2  ...       126           NaN       <NA>
# 1            2.5      3067         2  ...       202           NaN       <NA>
# 2            2.5      3067         2  ...       156          79.0       1900
# 3            2.5      3067         3  ...         0           NaN       <NA>
# 4            2.5      3067         3  ...       134         150.0       1900
#
#           CouncilArea  Latitude Longitude             RegionName  \
# 0  Yarra City Council  -37.8014  144.9958  Northern Metropolitan
# 1  Yarra City Council  -37.7996  144.9984  Northern Metropolitan
# 2  Yarra City Council  -37.8079  144.9934  Northern Metropolitan
# 3  Yarra City Council  -37.8114  145.0116  Northern Metropolitan
# 4  Yarra City Council  -37.8093  144.9944  Northern Metropolitan
#
#    NeighbouringProperties StreetName  StreetType
# 0                    4019    Studley      Street
# 1                    4019     Turner      Street
# 2                    4019  Bloomburg      Street
# 3                    4019   Victoria      Street
# 4                    4019    Charles      Street
#
# [5 rows x 22 columns]

# %%
df["UnitType"] = df["UnitType"].replace({"h": "House", "u": "Duplex", "t": "Town House"})
df.head()
# Out:
#        Suburb  Rooms UnitType    Price SaleMethod RealEstateAgent   SaleDate  \
# 0  Abbotsford      2    House     <NA>         SS          Jellis  3/09/2016
# 1  Abbotsford      2    House  1480000          S          Biggin  3/12/2016
# 2  Abbotsford      2    House  1035000          S          Biggin  4/02/2016
# 3  Abbotsford      3   Duplex     <NA>         VB          Rounds  4/02/2016
# 4  Abbotsford      3    House  1465000         SP          Biggin  4/03/2017
#
#    DistanceToCBD  Postcode  Bedrooms  ...  LandSize  BuildingArea  YearBuilt  \
# 0            2.5      3067         2  ...       126           NaN       <NA>
# 1            2.5      3067         2  ...       202           NaN       <NA>
# 2            2.5      3067         2  ...       156          79.0       1900
# 3            2.5      3067         3  ...         0           NaN       <NA>
# 4            2.5      3067         3  ...       134         150.0       1900
#
#           CouncilArea  Latitude Longitude             RegionName  \
# 0  Yarra City Council  -37.8014  144.9958  Northern Metropolitan
# 1  Yarra City Council  -37.7996  144.9984  Northern Metropolitan
# 2  Yarra City Council  -37.8079  144.9934  Northern Metropolitan
# 3  Yarra City Council  -37.8114  145.0116  Northern Metropolitan
# 4  Yarra City Council  -37.8093  144.9944  Northern Metropolitan
#
#    NeighbouringProperties StreetName  StreetType
# 0                    4019    Studley      Street
# 1                    4019     Turner      Street
# 2                    4019  Bloomburg      Street
# 3                    4019   Victoria      Street
# 4                    4019    Charles      Street
#
# [5 rows x 22 columns]

# %%
saleMethodAbbreviations = {"S": "Sold", "SP": "Sold Prior", "PI": "Passed In", "VB": "Vendor Bid",
                           "SN": "Sold Not Disclosed", "PN": "Sold Prior Not Disclosed", "SA": "Sold After Auction",
                           "W": "Withdrawn Prior to Auction", "SS": "Sold After Auction Not Disclosed"}
df["SaleMethod"] = df["SaleMethod"].replace(saleMethodAbbreviations)
df.head()
# Out:
#        Suburb  Rooms UnitType    Price                        SaleMethod  \
# 0  Abbotsford      2    House     <NA>  Sold After Auction Not Disclosed
# 1  Abbotsford      2    House  1480000                              Sold
# 2  Abbotsford      2    House  1035000                              Sold
# 3  Abbotsford      3   Duplex     <NA>                        Vendor Bid
# 4  Abbotsford      3    House  1465000                        Sold Prior
#
#   RealEstateAgent   SaleDate  DistanceToCBD  Postcode  Bedrooms  ...  \
# 0          Jellis  3/09/2016            2.5      3067         2  ...
# 1          Biggin  3/12/2016            2.5      3067         2  ...
# 2          Biggin  4/02/2016            2.5      3067         2  ...
# 3          Rounds  4/02/2016            2.5      3067         3  ...
# 4          Biggin  4/03/2017            2.5      3067         3  ...
#
#    LandSize  BuildingArea  YearBuilt         CouncilArea  Latitude Longitude  \
# 0       126           NaN       <NA>  Yarra City Council  -37.8014  144.9958
# 1       202           NaN       <NA>  Yarra City Council  -37.7996  144.9984
# 2       156          79.0       1900  Yarra City Council  -37.8079  144.9934
# 3         0           NaN       <NA>  Yarra City Council  -37.8114  145.0116
# 4       134         150.0       1900  Yarra City Council  -37.8093  144.9944
#
#               RegionName  NeighbouringProperties StreetName  StreetType
# 0  Northern Metropolitan                    4019    Studley      Street
# 1  Northern Metropolitan                    4019     Turner      Street
# 2  Northern Metropolitan                    4019  Bloomburg      Street
# 3  Northern Metropolitan                    4019   Victoria      Street
# 4  Northern Metropolitan                    4019    Charles      Street
#
# [5 rows x 22 columns]

# %%
df["SaleDate"] = pd.to_datetime(df["SaleDate"], format="mixed")
df.head()
# Out:
#        Suburb  Rooms UnitType    Price                        SaleMethod  \
# 0  Abbotsford      2    House     <NA>  Sold After Auction Not Disclosed
# 1  Abbotsford      2    House  1480000                              Sold
# 2  Abbotsford      2    House  1035000                              Sold
# 3  Abbotsford      3   Duplex     <NA>                        Vendor Bid
# 4  Abbotsford      3    House  1465000                        Sold Prior
#
#   RealEstateAgent   SaleDate  DistanceToCBD  Postcode  Bedrooms  ...  \
# 0          Jellis 2016-03-09            2.5      3067         2  ...
# 1          Biggin 2016-03-12            2.5      3067         2  ...
# 2          Biggin 2016-04-02            2.5      3067         2  ...
# 3          Rounds 2016-04-02            2.5      3067         3  ...
# 4          Biggin 2017-04-03            2.5      3067         3  ...
#
#    LandSize  BuildingArea  YearBuilt         CouncilArea  Latitude Longitude  \
# 0       126           NaN       <NA>  Yarra City Council  -37.8014  144.9958
# 1       202           NaN       <NA>  Yarra City Council  -37.7996  144.9984
# 2       156          79.0       1900  Yarra City Council  -37.8079  144.9934
# 3         0           NaN       <NA>  Yarra City Council  -37.8114  145.0116
# 4       134         150.0       1900  Yarra City Council  -37.8093  144.9944
#
#               RegionName  NeighbouringProperties StreetName  StreetType
# 0  Northern Metropolitan                    4019    Studley      Street
# 1  Northern Metropolitan                    4019     Turner      Street
# 2  Northern Metropolitan                    4019  Bloomburg      Street
# 3  Northern Metropolitan                    4019   Victoria      Street
# 4  Northern Metropolitan                    4019    Charles      Street
#
# [5 rows x 22 columns]

# %%
df["CouncilArea"] = df["CouncilArea"].str.replace(" Council", "")
df.head()
# Out:
#        Suburb  Rooms UnitType    Price                        SaleMethod  \
# 0  Abbotsford      2    House     <NA>  Sold After Auction Not Disclosed
# 1  Abbotsford      2    House  1480000                              Sold
# 2  Abbotsford      2    House  1035000                              Sold
# 3  Abbotsford      3   Duplex     <NA>                        Vendor Bid
# 4  Abbotsford      3    House  1465000                        Sold Prior
#
#   RealEstateAgent   SaleDate  DistanceToCBD  Postcode  Bedrooms  ...  \
# 0          Jellis 2016-03-09            2.5      3067         2  ...
# 1          Biggin 2016-03-12            2.5      3067         2  ...
# 2          Biggin 2016-04-02            2.5      3067         2  ...
# 3          Rounds 2016-04-02            2.5      3067         3  ...
# 4          Biggin 2017-04-03            2.5      3067         3  ...
#
#    LandSize  BuildingArea  YearBuilt  CouncilArea  Latitude Longitude  \
# 0       126           NaN       <NA>   Yarra City  -37.8014  144.9958
# 1       202           NaN       <NA>   Yarra City  -37.7996  144.9984
# 2       156          79.0       1900   Yarra City  -37.8079  144.9934
# 3         0           NaN       <NA>   Yarra City  -37.8114  145.0116
# 4       134         150.0       1900   Yarra City  -37.8093  144.9944
#
#               RegionName  NeighbouringProperties StreetName  StreetType
# 0  Northern Metropolitan                    4019    Studley      Street
# 1  Northern Metropolitan                    4019     Turner      Street
# 2  Northern Metropolitan                    4019  Bloomburg      Street
# 3  Northern Metropolitan                    4019   Victoria      Street
# 4  Northern Metropolitan                    4019    Charles      Street
#
# [5 rows x 22 columns]

# %%
nonAlNumLetters = set()
for column in df.select_dtypes(include=object).columns:
    for cell in df[column]:
        if isinstance(cell, str):
            for letter in cell:
                if not letter.isalnum():
                    nonAlNumLetters.add(letter)
nonAlNumLetters
# Out:
# {' ', '&', "'", '-', '.', '/', '@'}

# %%
for column in df.select_dtypes(include=object).columns:
    df[column] = df[column].str.strip().str.title()
    for nonAlNumLetter in nonAlNumLetters:
        df[column] = df[column].str.replace(nonAlNumLetter, "_")
    df[column] = df[column].str.strip("_")
df.head()
# Out:
#        Suburb  Rooms UnitType    Price                        SaleMethod  \
# 0  Abbotsford      2    House     <NA>  Sold_After_Auction_Not_Disclosed
# 1  Abbotsford      2    House  1480000                              Sold
# 2  Abbotsford      2    House  1035000                              Sold
# 3  Abbotsford      3   Duplex     <NA>                        Vendor_Bid
# 4  Abbotsford      3    House  1465000                        Sold_Prior
#
#   RealEstateAgent   SaleDate  DistanceToCBD  Postcode  Bedrooms  ...  \
# 0          Jellis 2016-03-09            2.5      3067         2  ...
# 1          Biggin 2016-03-12            2.5      3067         2  ...
# 2          Biggin 2016-04-02            2.5      3067         2  ...
# 3          Rounds 2016-04-02            2.5      3067         3  ...
# 4          Biggin 2017-04-03            2.5      3067         3  ...
#
#    LandSize  BuildingArea  YearBuilt  CouncilArea  Latitude Longitude  \
# 0       126           NaN       <NA>   Yarra_City  -37.8014  144.9958
# 1       202           NaN       <NA>   Yarra_City  -37.7996  144.9984
# 2       156          79.0       1900   Yarra_City  -37.8079  144.9934
# 3         0           NaN       <NA>   Yarra_City  -37.8114  145.0116
# 4       134         150.0       1900   Yarra_City  -37.8093  144.9944
#
#               RegionName  NeighbouringProperties StreetName  StreetType
# 0  Northern_Metropolitan                    4019    Studley      Street
# 1  Northern_Metropolitan                    4019     Turner      Street
# 2  Northern_Metropolitan                    4019  Bloomburg      Street
# 3  Northern_Metropolitan                    4019   Victoria      Street
# 4  Northern_Metropolitan                    4019    Charles      Street
#
# [5 rows x 22 columns]

# %%
df = df[df.select_dtypes(include=object).columns.tolist() + df.select_dtypes(exclude=object).columns.tolist()]
columns = ["SaleDate"] + [column for column in df.columns if column not in ["SaleDate", "Price"]] + ["Price"]
df = df[columns]
df.head()
# Out:
#     SaleDate      Suburb UnitType                        SaleMethod  \
# 0 2016-03-09  Abbotsford    House  Sold_After_Auction_Not_Disclosed
# 1 2016-03-12  Abbotsford    House                              Sold
# 2 2016-04-02  Abbotsford    House                              Sold
# 3 2016-04-02  Abbotsford   Duplex                        Vendor_Bid
# 4 2017-04-03  Abbotsford    House                        Sold_Prior
#
#   RealEstateAgent CouncilArea             RegionName StreetName StreetType  \
# 0          Jellis  Yarra_City  Northern_Metropolitan    Studley     Street
# 1          Biggin  Yarra_City  Northern_Metropolitan     Turner     Street
# 2          Biggin  Yarra_City  Northern_Metropolitan  Bloomburg     Street
# 3          Rounds  Yarra_City  Northern_Metropolitan   Victoria     Street
# 4          Biggin  Yarra_City  Northern_Metropolitan    Charles     Street
#
#    Rooms  ...  Bedrooms  Bathrooms  CarSpots  LandSize  BuildingArea  \
# 0      2  ...         2          1         1       126           NaN
# 1      2  ...         2          1         1       202           NaN
# 2      2  ...         2          1         0       156          79.0
# 3      3  ...         3          2         1         0           NaN
# 4      3  ...         3          2         0       134         150.0
#
#    YearBuilt  Latitude  Longitude  NeighbouringProperties    Price
# 0       <NA>  -37.8014   144.9958                    4019     <NA>
# 1       <NA>  -37.7996   144.9984                    4019  1480000
# 2       1900  -37.8079   144.9934                    4019  1035000
# 3       <NA>  -37.8114   145.0116                    4019     <NA>
# 4       1900  -37.8093   144.9944                    4019  1465000
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Nulls Estimation

# %%
df.isnull().sum()
# Out:
# SaleDate                      0
# Suburb                        0
# UnitType                      0
# SaleMethod                    0
# RealEstateAgent               0
# CouncilArea                   3
# RegionName                    3
# StreetName                    0
# StreetType                    0
# Rooms                         0
# DistanceToCBD                 1
# Postcode                      1
# Bedrooms                   8217
# Bathrooms                  8226
# CarSpots                   8728
# LandSize                  11810
# BuildingArea              21115
# YearBuilt                 19306
# Latitude                   7976
# Longitude                  7976
# NeighbouringProperties        3
# Price                      7610
# dtype: int64

# %%
df.dropna(subset=["Price"], inplace=True)
df.isnull().sum()
# Out:
# SaleDate                      0
# Suburb                        0
# UnitType                      0
# SaleMethod                    0
# RealEstateAgent               0
# CouncilArea                   3
# RegionName                    3
# StreetName                    0
# StreetType                    0
# Rooms                         0
# DistanceToCBD                 1
# Postcode                      1
# Bedrooms                   6441
# Bathrooms                  6447
# CarSpots                   6824
# LandSize                   9265
# BuildingArea              16591
# YearBuilt                 15163
# Latitude                   6254
# Longitude                  6254
# NeighbouringProperties        3
# Price                         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='median')
df["SaleDate"] = df["SaleDate"].astype("int64")
df[df.select_dtypes(exclude=object).columns] = imputer.fit_transform(df[df.select_dtypes(exclude=object).columns])
df["SaleDate"] = pd.to_datetime(df["SaleDate"])
df[df.select_dtypes(exclude=object).columns].isnull().sum()
# Out:
# SaleDate                  0
# Rooms                     0
# DistanceToCBD             0
# Postcode                  0
# Bedrooms                  0
# Bathrooms                 0
# CarSpots                  0
# LandSize                  0
# BuildingArea              0
# YearBuilt                 0
# Latitude                  0
# Longitude                 0
# NeighbouringProperties    0
# Price                     0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='most_frequent')
df[df.select_dtypes(include=object).columns] = imputer.fit_transform(df[df.select_dtypes(include=object).columns])
df[df.select_dtypes(include=object).columns].isnull().sum()
# Out:
# Suburb             0
# UnitType           0
# SaleMethod         0
# RealEstateAgent    0
# CouncilArea        0
# RegionName         0
# StreetName         0
# StreetType         0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# SaleDate                  0
# Suburb                    0
# UnitType                  0
# SaleMethod                0
# RealEstateAgent           0
# CouncilArea               0
# RegionName                0
# StreetName                0
# StreetType                0
# Rooms                     0
# DistanceToCBD             0
# Postcode                  0
# Bedrooms                  0
# Bathrooms                 0
# CarSpots                  0
# LandSize                  0
# BuildingArea              0
# YearBuilt                 0
# Latitude                  0
# Longitude                 0
# NeighbouringProperties    0
# Price                     0
# dtype: int64

# %% [markdown]
# ## Duplicates Removal

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)
